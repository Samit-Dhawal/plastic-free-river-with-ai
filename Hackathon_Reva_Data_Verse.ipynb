# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 15.0 MB/s eta 0:00:00
# ...

# %%
# Training the model

from ultralytics import YOLO
model = YOLO()
model.train(data="/content/drive/MyDrive/1_Reva_Data_Verse/data.yaml",epochs=100)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 69.9MB/s]
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
#Validating the model

# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data=/content/drive/MyDrive/1_Reva_Data_Verse/data.yaml
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/1_Reva_Data_Verse/valid/labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100% 10/10 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:03<00:00,  3.01s/it]
#                    all         10        255      0.638      0.471      0.443      0.203
# Speed: 15.1ms preprocess, 260.4ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val

# %%
#Predict with a custom model

# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/1_Reva_Data_Verse/test/images
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/30 /content/drive/MyDrive/1_Reva_Data_Verse/test/images/DJI_0310_jpg.rf.12e9c2ad19892a135fbcc4732b65619c.jpg: 640x640 13 plastics, 340.6ms
# image 2/30 /content/drive/MyDrive/1_Reva_Data_Verse/test/images/DJI_0314_jpg.rf.c3ffc40794848154c06a01cee709b3dd.jpg: 640x640 14 plastics, 216.4ms
# image 3/30 /content/drive/MyDrive/1_Reva_Data_Verse/test/images/DJI_0317_jpg.rf.c69f1cc6f115cc0198a3c64e547fd489.jpg: 640x640 6 plastics, 201.1ms
# image 4/30 /content/drive/MyDrive/1_Reva_Data_Verse/test/images/DJI_0346_jpg.rf.fd490428aa95217c6c3de2f081af8703.jpg: 640x640 6 plastics, 216.8ms
# image 5/30 /content/drive/MyDrive/1_Reva_Data_Verse/test/images/DJI_0347_jpg.rf.b2f1791222af790e382c2f89312af1c1.jpg: 640x640 5 plastics, 195.8ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/1_Reva_Data_Verse/valid/images
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/10 /content/drive/MyDrive/1_Reva_Data_Verse/valid/images/DJI_0023_jpg.rf.b0ca096a1352bc61e043f7abe9e759f1.jpg: 640x640 28 plastics, 252.1ms
# image 2/10 /content/drive/MyDrive/1_Reva_Data_Verse/valid/images/DJI_0080_jpg.rf.26dda137d199988455b7043e6a014830.jpg: 640x640 13 plastics, 214.6ms
# image 3/10 /content/drive/MyDrive/1_Reva_Data_Verse/valid/images/DJI_0088_jpg.rf.70f08fcbe5066a4bf6cdc4c4680a61cf.jpg: 640x640 2 plastics, 216.5ms
# image 4/10 /content/drive/MyDrive/1_Reva_Data_Verse/valid/images/DJI_0185_jpg.rf.a61b665b8e3b568ed6f0bd46f97af517.jpg: 640x640 15 plastics, 199.0ms
# image 5/10 /content/drive/MyDrive/1_Reva_Data_Verse/valid/images/DJI_0205_jpg.rf.69e9800195fbcdfdc97dc02917bb0213.jpg: 640x640 3 plastics, 206.9ms
# ...

# %%
# !pip install onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 50.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.5 MB/s eta 0:00:00
# ...

# %%
model.export(format='onnx',imgsz=[640,640])
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# PyTorch: starting from runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 47.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 22.2s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 24.4s, saved as runs/detect/train/weights/best.onnx (11.7 MB)
#
# Export complete (25.4s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# ...
